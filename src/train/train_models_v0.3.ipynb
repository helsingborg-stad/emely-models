# %% [markdown]
# # Training Emely
#
# This notebook is for training Emely with different configurations.
# Use the blender_opts dictionary for the standard options.
#
# ### Configuration
#
# #### Base Config
# We'll call the base configuration "Blender base config" and it's the blender 90M model fine tuned on the internal and external tasks
#
# ### Required config for a run
#
# - task
# - multitask_weights
# - model_file
#
# ### Optional config
# - mutators
# - lr
#
#
# ### Different mutators for different tasks?
# --task internal:mutators=word_shuffle,internal:mutators=last_turn
#
#
# ### Evaluation
# All models are evaluated on the internal and external tasks

# %%
from parlai.scripts.train_model import TrainModel
from pathlib import Path
from copy import deepcopy
import shutil

# %%
blender_opts = {'init_model': 'zoo:blender/blender_90M/model',
                'dict_file': 'zoo:blender/blender_90M/model.dict',
              'model': 'transformer/generator',
              'embedding_size': 512,
              'n_layers': 8,
              'ffn_size': 2048,
              'dropout': 0.1,
              'n_heads': 16,
              'learn_positional_embeddings': True,
              'n_positions': 512,
              'variant': 'xlm',
              'activation': 'gelu',
              'fp16': True,
              'text_truncate': 512,
              'label_truncate': 128,
              'dict_tokenizer': 'bpe',
              'optimizer': 'adamax',
              'lr_scheduler': 'reduceonplateau',
              'betas': '0.9,0.999',
              'update_freq': 1,
              'attention_dropout': 0.0,
              'relu_dropout': 0.0,
              'dict_lower': True,
              'lr': 1e-06,
              'gradient_clip': 0.1,
              'veps': 0.25,
              'skip_generation': False,
              'vp': 15,
              'stim': 60,
              'vme': 20000,
              'bs': 16,
              'vmt': 'ppl',
              'vmm': 'min',
              'save_after_valid': True,
              'wblog': True,
              'wandb_project': 'parlaiemely',
              'tensorboard_log': True,
              'metrics': 'ppl,bleu-4,rouge-L',
              'evaltask': 'internal,external',
              'inference': 'beam',
              'beam_size': 10,
              'beam_min_length': 10,
              'beam_block_ngram': 3
               }

#              'dict_file': 'zoo:blender/blender_90M/model.dict'

# %%
def run_training(tasks, weights, mutators=None):

    # Set name for file and model run on wandb
    if mutators is not None:
        name = f'blender-{tasks}-{weights}-{mutators}'

    else:
        name = f'blender-{tasks}-{weights}'

        
    #%env WANDB_NAME=$name
    mf = Path.cwd().parents[1].joinpath(f'models/model-runs/{name}/model')
    
    if mutators is not None:
        run_opts = {'task': tasks,
                    'multitask_weights': weights,
                    'model_file': mf.as_posix(),
                    'mutators': mutators
                    }        
    else:
        run_opts = {'task': tasks,
                    'multitask_weights': weights,
                    'model_file': mf.as_posix()
                   }
    
    # Copy the standard opts and update them
    opts = deepcopy(blender_opts)
    opts.update(run_opts)

    TrainModel.main(**opts)

# %% [markdown]
# ## 0. Test run 2 after each other

# %%
name = 'TEST'
mf = Path.cwd().parents[1].joinpath(f'models/model-runs/{name}/model')

if mf.parent.exists():
    shutil.rmtree(mf.parent)

tasks = 'internal,external'
weights='5,1'
mutators='word_shuffle'
run_training(tasks=tasks,weights=weights, mutators=mutators)

# %% [markdown]
# ## 1. Blender base config
#
# ### Datasets with sampling weights:
# - internal - 6
# - external - 3
#
# ### Mutators
# None

# %%
tasks='internal,external'
weights= '6,3'

run_training(tasks=tasks,weights=weights)
# Out:
# 18:25:42 | building dictionary first...
# 18:25:42 | No model with opt yet at: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model(.opt)
# 18:25:42 | your model is being loaded with opts that do not exist in the model you are initializing the weights with: allow_missing_init_opts: False,download_path: None,loglevel: info,dynamic_batching: None,verbose: False,is_debug: False,datapath: /home/alex/ParlaiEmely/ParlAI/data,eval_dynamic_batching: None,num_workers: 0,max_train_steps: -1,log_every_n_steps: 50,validation_every_n_steps: -1,load_from_checkpoint: True,tensorboard_logdir: None,wandb_log: True,wandb_name: None,wandb_project: parlaiemely,wandb_entity: None,mutators: None,n_encoder_layers: -1,n_decoder_layers: -1,model_parallel: False,beam_block_full_context: True,beam_delay: 30,beam_block_list_filename: None,temperature: 1.0,interactive_mode: False,history_reversed: False,history_add_global_end_token: None,special_tok_lst: None,bpe_vocab: None,bpe_merge: None,bpe_add_prefix_space: None,bpe_dropout: None
# 18:25:42 | your model is being loaded with opts that differ from the model you are initializing the weights with. Add the following args to your run command to change this:
# --show-advanced-args False --task internal:blended_skill_talk,wizard_of_wikipedia,convai2,empathetic_dialogues --numthreads 1 --multitask-weights 1.0,3.0,3.0,3.0 --evaltask None --metrics default --tensorboard-log False --log-every-n-secs 2 --label-type response --include-knowledge True --include-checked-sentence True --include-knowledge-separator False --num-topics 5 --train-experiencer-only False --beam-min-length 20 --beam-context-block-ngram 3 --fp16-impl apex --learningrate 7.5e-06 --max-lr-steps -1 --parlai-home /private/home/edinan/ParlAI
# 18:25:42 | Using CUDA
# 18:25:42 | loading dictionary from /home/alex/ParlaiEmely/ParlAI/data/models/blender/blender_90M/model.dict
# 18:25:42 | num words = 54944
# 18:25:43 | DEPRECATED: XLM should only be used for backwards compatibility, as it involves a less-stable layernorm operation.
# 18:25:46 | Total parameters: 87,508,992 (87,508,992 trainable)
# 18:25:46 | Loading existing model params from /home/alex/ParlaiEmely/ParlAI/data/models/blender/blender_90M/model
# 18:25:46 | Opt:
# 18:25:46 |     activation: gelu
# 18:25:46 |     adafactor_eps: '(1e-30, 0.001)'
# 18:25:46 |     adam_eps: 1e-08
# 18:25:46 |     add_p1_after_newln: False
# 18:25:46 |     aggregate_micro: False
# 18:25:46 |     allow_missing_init_opts: False
# 18:25:46 |     attention_dropout: 0.0
# 18:25:46 |     batchsize: 16
# 18:25:46 |     beam_block_full_context: True
# 18:25:46 |     beam_block_list_filename: None
# 18:25:46 |     beam_block_ngram: 3
# 18:25:46 |     beam_context_block_ngram: -1
# 18:25:46 |     beam_delay: 30
# 18:25:46 |     beam_length_penalty: 0.65
# 18:25:46 |     beam_min_length: 10
# 18:25:46 |     beam_size: 10
# 18:25:46 |     betas: '(0.9, 0.999)'
# 18:25:46 |     bpe_add_prefix_space: None
# 18:25:46 |     bpe_debug: False
# 18:25:46 |     bpe_dropout: None
# 18:25:46 |     bpe_merge: None
# 18:25:46 |     bpe_vocab: None
# 18:25:46 |     compute_tokenized_bleu: False
# 18:25:46 |     datapath: /home/alex/ParlaiEmely/ParlAI/data
# 18:25:46 |     datatype: train
# 18:25:46 |     delimiter: '\n'
# 18:25:46 |     dict_class: parlai.core.dict:DictionaryAgent
# 18:25:46 |     dict_endtoken: __end__
# 18:25:46 |     dict_file: /home/alex/ParlaiEmely/ParlAI/data/models/blender/blender_90M/model.dict
# 18:25:46 |     dict_include_test: False
# 18:25:46 |     dict_include_valid: False
# 18:25:46 |     dict_initpath: None
# 18:25:46 |     dict_language: english
# 18:25:46 |     dict_loaded: True
# 18:25:46 |     dict_lower: True
# 18:25:46 |     dict_max_ngram_size: -1
# 18:25:46 |     dict_maxexs: -1
# 18:25:46 |     dict_maxtokens: -1
# 18:25:46 |     dict_minfreq: 0
# 18:25:46 |     dict_nulltoken: __null__
# 18:25:46 |     dict_starttoken: __start__
# 18:25:46 |     dict_textfields: text,labels
# 18:25:46 |     dict_tokenizer: bpe
# 18:25:46 |     dict_unktoken: __unk__
# 18:25:46 |     display_examples: False
# 18:25:46 |     download_path: None
# 18:25:46 |     dropout: 0.1
# 18:25:46 |     dynamic_batching: None
# 18:25:46 |     embedding_projection: random
# 18:25:46 |     embedding_size: 512
# 18:25:46 |     embedding_type: random
# 18:25:46 |     embeddings_scale: True
# 18:25:46 |     eval_batchsize: None
# 18:25:46 |     eval_dynamic_batching: None
# 18:25:46 |     evaltask: internal,external
# 18:25:46 |     ffn_size: 2048
# 18:25:46 |     force_fp16_tokens: False
# 18:25:46 |     fp16: True
# 18:25:46 |     fp16_impl: safe
# 18:25:46 |     gpu: -1
# 18:25:46 |     gradient_clip: 0.1
# 18:25:46 |     hide_labels: False
# 18:25:46 |     history_add_global_end_token: None
# 18:25:46 |     history_reversed: False
# 18:25:46 |     history_size: -1
# 18:25:46 |     image_cropsize: 224
# 18:25:46 |     image_mode: raw
# 18:25:46 |     image_size: 256
# 18:25:46 |     inference: beam
# 18:25:46 |     init_model: /home/alex/ParlaiEmely/ParlAI/data/models/blender/blender_90M/model
# 18:25:46 |     init_opt: None
# 18:25:46 |     interactive_mode: False
# 18:25:46 |     invsqrt_lr_decay_gamma: -1
# 18:25:46 |     is_debug: False
# 18:25:46 |     label_truncate: 128
# 18:25:46 |     learn_positional_embeddings: True
# 18:25:46 |     learningrate: 1e-06
# 18:25:46 |     load_from_checkpoint: True
# 18:25:46 |     log_every_n_secs: -1
# 18:25:46 |     log_every_n_steps: 50
# 18:25:46 |     loglevel: info
# 18:25:46 |     lr_scheduler: reduceonplateau
# 18:25:46 |     lr_scheduler_decay: 0.5
# 18:25:46 |     lr_scheduler_patience: 3
# 18:25:46 |     max_train_steps: -1
# 18:25:46 |     max_train_time: -1
# 18:25:46 |     metrics: ppl,bleu-4,rouge-L
# 18:25:46 |     model: transformer/generator
# 18:25:46 |     model_file: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:25:46 |     model_parallel: False
# 18:25:46 |     momentum: 0
# 18:25:46 |     multitask_weights: '(6.0, 3.0)'
# 18:25:46 |     mutators: None
# 18:25:46 |     n_decoder_layers: -1
# 18:25:46 |     n_encoder_layers: -1
# 18:25:46 |     n_heads: 16
# 18:25:46 |     n_layers: 8
# 18:25:46 |     n_positions: 512
# 18:25:46 |     n_segments: 0
# 18:25:46 |     nesterov: True
# 18:25:46 |     no_cuda: False
# 18:25:46 |     num_epochs: -1
# 18:25:46 |     num_workers: 0
# 18:25:46 |     nus: (0.7,)
# 18:25:46 |     optimizer: adamax
# 18:25:46 |     output_scaling: 1.0
# 18:25:46 |     override: "{'init_model': 'zoo:blender/blender_90M/model', 'dict_file': '/home/alex/ParlaiEmely/ParlAI/data/models/blender/blender_90M/model.dict', 'model': 'transformer/generator', 'embedding_size': 512, 'n_layers': 8, 'ffn_size': 2048, 'dropout': 0.1, 'n_heads': 16, 'learn_positional_embeddings': True, 'n_positions': 512, 'variant': 'xlm', 'activation': 'gelu', 'fp16': True, 'text_truncate': 512, 'label_truncate': 128, 'dict_tokenizer': 'bpe', 'optimizer': 'adamax', 'lr_scheduler': 'reduceonplateau', 'betas': (0.9, 0.999), 'update_freq': 1, 'attention_dropout': 0.0, 'relu_dropout': 0.0, 'dict_lower': True, 'learningrate': 1e-06, 'gradient_clip': 0.1, 'validation_every_n_epochs': 0.25, 'skip_generation': False, 'validation_patience': 15, 'save_every_n_secs': 60.0, 'validation_max_exs': 20000, 'batchsize': 16, 'validation_metric': 'ppl', 'validation_metric_mode': 'min', 'save_after_valid': True, 'wandb_log': True, 'wandb_project': 'parlaiemely', 'tensorboard_log': True, 'metrics': 'ppl,bleu-4,rouge-L', 'evaltask': 'internal,external', 'inference': 'beam', 'beam_size': 10, 'beam_min_length': 10, 'beam_block_ngram': 3, 'task': 'internal,external', 'multitask_weights': (6.0, 3.0), 'model_file': '/home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model'}"
# 18:25:46 |     parlai_home: /home/alex/ParlaiEmely/ParlAI
# 18:25:46 |     person_tokens: False
# 18:25:46 |     rank_candidates: False
# 18:25:46 |     relu_dropout: 0.0
# 18:25:46 |     save_after_valid: True
# 18:25:46 |     save_every_n_secs: 60.0
# 18:25:46 |     share_word_embeddings: True
# 18:25:46 |     short_final_eval: False
# 18:25:46 |     skip_generation: False
# 18:25:46 |     special_tok_lst: None
# 18:25:46 |     split_lines: False
# 18:25:46 |     starttime: Jun17_18-25
# 18:25:46 |     task: internal,external
# 18:25:46 |     temperature: 1.0
# 18:25:46 |     tensorboard_log: True
# 18:25:46 |     tensorboard_logdir: None
# 18:25:46 |     text_truncate: 512
# 18:25:46 |     topk: 10
# 18:25:46 |     topp: 0.9
# 18:25:46 |     truncate: -1
# 18:25:46 |     update_freq: 1
# 18:25:46 |     use_reply: label
# 18:25:46 |     validation_cutoff: 1.0
# 18:25:46 |     validation_every_n_epochs: 0.25
# 18:25:46 |     validation_every_n_secs: -1
# 18:25:46 |     validation_every_n_steps: -1
# 18:25:46 |     validation_max_exs: 20000
# 18:25:46 |     validation_metric: ppl
# 18:25:46 |     validation_metric_mode: min
# 18:25:46 |     validation_patience: 15
# 18:25:46 |     validation_share_agent: False
# 18:25:46 |     variant: xlm
# 18:25:46 |     verbose: False
# 18:25:46 |     wandb_entity: None
# 18:25:46 |     wandb_log: True
# 18:25:46 |     wandb_name: None
# 18:25:46 |     wandb_project: parlaiemely
# 18:25:46 |     warmup_rate: 0.0001
# 18:25:46 |     warmup_updates: -1
# 18:25:46 |     weight_decay: None
# 18:25:46 | Current ParlAI commit: e3c1edbef397de2c084a521fb0bb81489a432c74
# 18:25:46 | creating task(s): internal,external
# 18:25:46 | Loading ParlAI text data: /home/alex/ParlaiEmely/ParlAI/data/internal/train.txt
# 18:25:46 | Loading ParlAI text data: /home/alex/ParlaiEmely/ParlAI/data/external/train.txt
# wandb: W&B API key is configured (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">gallant-lake-15</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/bornhagel/parlaiemely" target="_blank">https://wandb.ai/bornhagel/parlaiemely</a><br/>
#                 Run page: <a href="https://wandb.ai/bornhagel/parlaiemely/runs/3cpjky7n" target="_blank">https://wandb.ai/bornhagel/parlaiemely/runs/3cpjky7n</a><br/>
#                 Run data is saved locally in <code>/home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/wandb/run-20210617_182552-3cpjky7n</code><br/><br/>
# 18:26:09 | training...
# 18:26:11 | time:25s total_exs:256 total_steps:16 epochs:0.26
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      55.46     1 884.4  7331       0          0 132.6  256             32768  12.56    .1370 15.49 2.844 1e-06 245.9
#    external 56.23                         0          0         97                                   15.99 3.041
#    internal 54.69                         0          0        159                                   14.99 2.647
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb  tps   ups
#    all       2038       0          0 17.51      .4114         0                   16 1130 9370 8.348
#    external             0          0 20.92      .3830         0
#    internal             0          0 14.11      .4398         0
#
# 18:26:11 | creating task(s): internal
# 18:26:11 | Loading ParlAI text data: /home/alex/ParlaiEmely/ParlAI/data/internal/valid.txt
# 18:26:11 | creating task(s): external
# 18:26:11 | Loading ParlAI text data: /home/alex/ParlaiEmely/ParlAI/data/external/valid.txt
# 18:26:11 | running eval: valid
# 18:26:28 | eval completed in 17.55s
# 18:26:28 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .00651 53.69 635.2 452.7       0          0 10.06  171 .1617    .0691 14.68 2.814 1e-06   190 135.4
#    external         0 .009921 62.36                   0          0         44 .1519          15.89 3.083
#    internal         0 .003099 45.02                   0          0        127 .1716          13.46 2.544
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 17.28    .1633      .4268         0                   16 825.2 588.1
#    external       0          0 21.83    .1536      .3991         0
#    internal       0          0 12.73    .1729      .4544         0
#
# 18:26:29 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:26:29 | Saving dictionary to /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint.dict
# 18:26:30 | new best ppl: 17.28
# 18:26:30 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:26:30 | Saving dictionary to /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.dict
# 18:26:32 | time:46s total_exs:512 total_steps:32 epochs:0.53
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      51.25     1 835.1  9721       0          0 186.2  256             32768  13.01    .1158 13.73  2.83 1e-06 219.9
#    external 48.57                         0          0         83                                   13.69 3.023
#    internal 53.94                         0          0        173                                   13.77 2.636
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2559       0          0 17.26      .4216         0                   32 1055 12280 11.65
#    external             0          0 20.56      .3944         0
#    internal             0          0 13.96      .4488         0
#
# 18:26:32 | running eval: valid
# 18:26:49 | eval completed in 16.97s
# 18:26:49 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .006204 53.69 635.2 472.1       0          0 10.49  171 .1713   .06921 14.68 2.799 1e-06   190 141.2
#    external         0 .009921 62.36                   0          0         44 .1580          15.89  3.07
#    internal         0 .002487 45.02                   0          0        127 .1845          13.46 2.527
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 17.03    .1720      .4282         0                   32 825.2 613.2
#    external       0          0 21.55    .1581      .3991         0
#    internal       0          0 12.52    .1859      .4573         0
#
# 18:26:49 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:26:51 | new best ppl: 17.03 (previous best was 17.28)
# 18:26:51 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:26:52 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:26:55 | time:69s total_exs:768 total_steps:48 epochs:0.79
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      55.77     1 890.6  9796       0          0   176  256             32768     12    .1114 14.25  2.78 1e-06 225.2
#    external 56.17                         0          0         92                                   14.88 3.094
#    internal 55.37                         0          0        164                                   13.63 2.467
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2478       0          0 16.92      .4314         0                   48 1116 12273 11.01
#    external             0          0 22.06      .3952         0
#    internal             0          0 11.79      .4676         0
#
# 18:26:55 | running eval: valid
# 18:27:12 | eval completed in 16.80s
# 18:27:12 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .007016 53.69 635.2 470.8       0          0 10.46  171 .1721   .06938 14.68 2.782 1e-06   190 140.8
#    external         0 .009779 62.36                   0          0         44 .1549          15.89 3.056
#    internal         0 .004254 45.02                   0          0        127 .1892          13.46 2.509
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 16.77    .1721      .4294         0                   48 825.2 611.6
#    external       0          0 21.24    .1564      .3991         0
#    internal       0          0 12.29    .1878      .4596         0
#
# 18:27:12 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:27:13 | new best ppl: 16.77 (previous best was 17.03)
# 18:27:13 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:27:16 | time:90s total_exs:1024 total_steps:64 epochs:1.06
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      54.06     1 866.1  8989       0          0   166  256             32768  12.65    .1223  14.3 2.879 1e-06 230.2
#    external 53.74                         0          0         99                                   13.92 3.058
#    internal 54.38                         0          0        157                                   14.68   2.7
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2389       0          0 18.08      .4128         0                   64 1096 11378 10.38
#    external             0          0 21.29      .3752         0
#    internal             0          0 14.88      .4503         0
# 18:27:16 | running eval: valid
# 18:27:31 | eval completed in 15.48s
# 18:27:31 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .007787 53.69 635.2 512.6       0          0 11.39  171 .1783   .06922 14.68 2.767 1e-06   190 153.3
#    external         0 .009779 62.36                   0          0         44 .1576          15.89 3.042
#    internal         0 .005794 45.02                   0          0        127 .1990          13.46 2.492
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 16.52    .1777      .4361         0                   64 825.2 665.9
#    external       0          0 20.96    .1570      .4049         0
#    internal       0          0 12.09    .1984      .4673         0
#
# 18:27:31 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:27:33 | new best ppl: 16.52 (previous best was 16.77)
# 18:27:33 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:27:36 | time:109s total_exs:1280 total_steps:80 epochs:1.32
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      56.83     1 908.1  9664       0          0 170.3  256             32768  13.35    .1253  14.3 2.894 1e-06 226.9
#    external 57.24                         0          0        104                                   14.95 3.175
#    internal 56.43                         0          0        152                                   13.65 2.612
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2414       0          0 18.78      .4212         0                   80 1135 12078 10.65
#    external             0          0 23.94      .4039         0
#    internal             0          0 13.62      .4386         0
#
# 18:27:36 | running eval: valid
# 18:27:51 | eval completed in 15.06s
# 18:27:51 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .01103 53.69 635.2 525.9       0          0 11.68  171 .1864   .06904 14.68 2.754 1e-06   190 157.3
#    external         0   .0179 62.36                   0          0         44 .1686          15.89 3.031
#    internal         0 .004156 45.02                   0          0        127 .2042          13.46 2.478
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 16.32    .1807      .4344         0                   80 825.2 683.2
#    external       0          0 20.72    .1650      .3991         0
#    internal       0          0 11.91    .1963      .4696         0
#
# 18:27:51 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:27:52 | new best ppl: 16.32 (previous best was 16.52)
# 18:27:52 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:27:53 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:27:56 | time:130s total_exs:1536 total_steps:96 epochs:1.59
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all       55.3     1 886.4  5573       0          0 100.6  256             32768  12.92    .1146 14.31 2.855 1e-06 229.4
#    external  54.1                         0          0        118                                   13.98 3.058
#    internal 56.51                         0          0        138                                   14.64 2.652
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb  tps  ups
#    all       1442       0          0 17.73      .4233         0                   96 1116 7016 6.29
#    external             0          0 21.28      .3982         0
#    internal             0          0 14.18      .4485         0
#
# 18:27:56 | running eval: valid
# 18:28:11 | eval completed in 14.89s
# 18:28:11 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .01693 53.69 635.2 531.8       0          0 11.81  171 .1953   .06913 14.68 2.743 1e-06   190 159.1
#    external         0  .02541 62.36                   0          0         44 .1839          15.89  3.02
#    internal         0 .008447 45.02                   0          0        127 .2067          13.46 2.465
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 16.13    .1932      .4357         0                   96 825.2 690.8
#    external       0          0 20.49    .1857      .4006         0
#    internal       0          0 11.77    .2008      .4708         0
#
# 18:28:11 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:28:12 | new best ppl: 16.13 (previous best was 16.32)
# 18:28:12 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:28:17 | time:150s total_exs:1792 total_steps:112 epochs:1.85
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      54.87     1 873.4  4628       0          0 84.78  256             32768  11.89    .1280 14.23 2.701 1e-06 221.7
#    external 55.62                         0          0         79                                   15.22 2.898
#    internal 54.12                         0          0        177                                   13.25 2.503
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb  tps   ups
#    all       1175       0          0 15.18      .4274         0                  112 1095 5802 5.301
#    external             0          0 18.14      .3960         0
#    internal             0          0 12.22      .4588         0
#
# 18:28:17 | running eval: valid
# 18:28:32 | eval completed in 15.49s
# 18:28:32 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .009118 53.69 635.2   508       0          0 11.28  171 .1924    .0692 14.68 2.733 1e-06   190 151.9
#    external         0 .009788 62.36                   0          0         44 .1729          15.89 3.011
#    internal         0 .008447 45.02                   0          0        127 .2118          13.46 2.454
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 15.97    .1897      .4345         0                  112 825.2 659.9
#    external       0          0 20.31    .1729      .3977         0
#    internal       0          0 11.64    .2064      .4713         0
#
# 18:28:32 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:28:34 | new best ppl: 15.97 (previous best was 16.13)
# 18:28:34 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:28:37 | time:170s total_exs:2048 total_steps:128 epochs:2.12
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      56.72     1 904.1  8527       0          0 150.9  256             32768  12.16    .1534 14.14 2.789 1e-06 225.9
#    external 58.45                         0          0        112                                   14.36 3.033
#    internal 54.99                         0          0        144                                   13.93 2.545
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2130       0          0 16.75      .4265         0                  128 1130 10658 9.439
#    external             0          0 20.76      .3918         0
#    internal             0          0 12.74      .4611         0
# 18:28:37 | running eval: valid
# 18:28:51 | eval completed in 14.89s
# 18:28:51 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .01258 53.69 635.2 528.4       0          0 11.74  171 .1957   .06921 14.68 2.724 1e-06   190   158
#    external         0  .01791 62.36                   0          0         44 .1775          15.89 3.003
#    internal         0 .007256 45.02                   0          0        127 .2139          13.46 2.444
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 15.83    .1923      .4397         0                  128 825.2 686.4
#    external       0          0 20.15    .1774      .4034         0
#    internal       0          0 11.52    .2072      .4760         0
#
# 18:28:52 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:28:53 | new best ppl: 15.83 (previous best was 15.97)
# 18:28:53 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:28:55 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:28:57 | time:191s total_exs:2304 total_steps:144 epochs:2.38
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      55.19     1 888.6  4952       0          0 89.16  256             32768  12.35    .1427 14.85 2.867 1e-06 229.1
#    external 54.12                         0          0         86                                   16.47 3.189
#    internal 56.26                         0          0        170                                   13.23 2.546
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb  tps   ups
#    all       1277       0          0  18.5      .3985         0                  144 1118 6229 5.575
#    external             0          0 24.25      .3425         0
#    internal             0          0 12.75      .4544         0
#
# 18:28:57 | running eval: valid
# 18:29:11 | eval completed in 14.26s
# 18:29:11 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .007574 53.69 635.2 552.5       0          0 12.27  171 .1977   .06932 14.68 2.716 1e-06   190 165.2
#    external         0 .009793 62.36                   0          0         44 .1780          15.89 2.996
#    internal         0 .005355 45.02                   0          0        127 .2175          13.46 2.436
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 15.71    .1944      .4429         0                  144 825.2 717.7
#    external       0          0    20    .1771      .4063         0
#    internal       0          0 11.42    .2116      .4795         0
#
# 18:29:11 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:29:13 | new best ppl: 15.71 (previous best was 15.83)
# 18:29:13 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:29:15 | time:209s total_exs:2560 total_steps:160 epochs:2.65
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      59.02     1 940.1  9873       0          0   168  256             32768  12.02    .1393 14.21 2.699 1e-06 226.8
#    external 60.62                         0          0        107                                    14.4 2.921
#    internal 57.42                         0          0        149                                   14.01 2.476
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2382       0          0 15.23      .4294         0                  160 1167 12255 10.51
#    external             0          0 18.56      .3952         0
#    internal             0          0 11.89      .4636         0
#
# 18:29:15 | running eval: valid
# 18:29:30 | eval completed in 14.21s
# 18:29:30 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .007573 53.69 635.2 563.3       0          0 12.51  171 .1984   .06912 14.68 2.709 1e-06   190 168.5
#    external         0 .009793 62.36                   0          0         44 .1783          15.89  2.99
#    internal         0 .005352 45.02                   0          0        127 .2186          13.46 2.428
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 15.61    .1944      .4452         0                  160 825.2 731.8
#    external       0          0 19.89    .1771      .4092         0
#    internal       0          0 11.33    .2117      .4813         0
#
# 18:29:30 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:29:31 | new best ppl: 15.61 (previous best was 15.71)
# 18:29:31 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:29:34 | time:228s total_exs:2816 total_steps:176 epochs:2.91
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      56.31     1 893.1  8033       0          0 143.9  256             32768   11.7    .1454 14.07 2.648 1e-06   225
#    external 57.66                         0          0         82                                   14.09 2.817
#    internal 54.95                         0          0        174                                   14.05  2.48
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2024       0          0 14.33      .4368         0                  176 1118 10057 9.001
#    external             0          0 16.73      .3931         0
#    internal             0          0 11.94      .4806         0
#
# 18:29:34 | running eval: valid
# 18:29:49 | eval completed in 14.41s
# 18:29:49 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .009823 53.69 635.2 542.8       0          0 12.06  171 .2025   .06907 14.68 2.702 1e-06   190 162.3
#    external         0 .009793 62.36                   0          0         44 .1763          15.89 2.984
#    internal         0 .009854 45.02                   0          0        127 .2286          13.46  2.42
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 15.51    .2003      .4462         0                  176 825.2 705.1
#    external       0          0 19.78    .1761      .4106         0
#    internal       0          0 11.25    .2245      .4819         0
#
# 18:29:49 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:29:50 | new best ppl: 15.51 (previous best was 15.61)
# 18:29:50 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:29:53 | time:246s total_exs:3072 total_steps:192 epochs:3.18
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all      54.34 .9375 872.9  9393       0          0 172.1  256             30720    .1165 14.12 2.807 1e-06 225.1  2422
#    external  52.6                         0          0        112                            14.51 3.038
#    internal 56.08                         0          0        144                            13.72 2.576
#              ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all            0          0    17      .4167         0                  192 1098 11814 10.77
#    external       0          0 20.86      .3815         0
#    internal       0          0 13.15      .4519         0
# WARNING:root:NaN or Inf found in input tensor.
# 18:29:53 | running eval: valid
# 18:30:07 | eval completed in 13.98s
# 18:30:07 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .009824 53.69 635.2 562.2       0          0 12.49  171 .2000   .06906 14.68 2.697 1e-06   190 168.1
#    external         0 .009793 62.36                   0          0         44 .1722          15.89 2.979
#    internal         0 .009855 45.02                   0          0        127 .2278          13.46 2.414
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 15.43    .1988      .4457         0                  192 825.2 730.3
#    external       0          0 19.67    .1728      .4077         0
#    internal       0          0 11.18    .2248      .4836         0
#
# 18:30:07 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:30:08 | new best ppl: 15.43 (previous best was 15.51)
# 18:30:08 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:30:09 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:30:13 | time:267s total_exs:3328 total_steps:208 epochs:3.44
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      56.46     1 906.8  5745       0          0 101.4  256             16384  11.48    .1167  14.7 2.683 1e-06 238.9
#    external 55.71                         0          0         91                                   13.92 2.808
#    internal  57.2                         0          0        165                                   15.48 2.558
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb  tps   ups
#    all       1513       0          0 14.75      .4350         0                  208 1146 7258 6.339
#    external             0          0 16.58      .4270         0
#    internal             0          0 12.91      .4431         0
#
# 18:30:13 | running eval: valid
# 18:30:27 | eval completed in 13.61s
# 18:30:27 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .01388 53.69 635.2 579.5       0          0 12.87  171 .2019   .06913 14.68 2.691 1e-06   190 173.3
#    external         0  .01791 62.36                   0          0         44 .1767          15.89 2.974
#    internal         0 .009855 45.02                   0          0        127 .2272          13.46 2.408
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 15.35    .2029      .4483         0                  208 825.2 752.9
#    external       0          0 19.58    .1818      .4106         0
#    internal       0          0 11.11    .2240      .4860         0
#
# 18:30:27 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:30:28 | new best ppl: 15.35 (previous best was 15.43)
# 18:30:28 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:30:31 | time:284s total_exs:3584 total_steps:224 epochs:3.71
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      55.22     1 870.3 11122       0          0 204.5  256             16384  11.16    .1213 14.95 2.631 1e-06 239.8
#    external 57.62                         0          0         84                                   14.85 2.736
#    internal 52.82                         0          0        172                                   15.06 2.527
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       3065       0          0 13.97      .4540         0                  224 1110 14186 12.79
#    external             0          0 15.42      .4370         0
#    internal             0          0 12.52      .4710         0
#
# 18:30:31 | running eval: valid
# 18:30:44 | eval completed in 13.53s
# 18:30:44 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .01416 53.69 635.2 589.8       0          0  13.1  171 .2039   .06916 14.68 2.686 1e-06   190 176.4
#    external         0  .01791 62.36                   0          0         44 .1823          15.89  2.97
#    internal         0   .0104 45.02                   0          0        127 .2256          13.46 2.402
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 15.27    .2024      .4497         0                  224 825.2 766.2
#    external       0          0 19.48    .1818      .4134         0
#    internal       0          0 11.05    .2231      .4860         0
#
# 18:30:44 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:30:45 | new best ppl: 15.27 (previous best was 15.35)
# 18:30:45 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:30:48 | time:302s total_exs:3840 total_steps:240 epochs:3.97
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all       56.8     1 910.8 10532       0          0   185  256             16384  11.51    .1454 14.75 2.767 1e-06 234.1
#    external 55.73                         0          0        113                                    15.8 3.052
#    internal 57.87                         0          0        143                                   13.71 2.483
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2707       0          0 16.57      .4323   .003497                  240 1145 13239 11.57
#    external             0          0 21.16      .3938         0
#    internal             0          0 11.97      .4707   .006993
#
# 18:30:48 | running eval: valid
# 18:31:02 | eval completed in 13.46s
# 18:31:02 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0   .0101 53.69 635.2 585.3       0          0    13  171 .1998   .06912 14.68 2.681 1e-06   190 175.1
#    external         0 .009789 62.36                   0          0         44 .1735          15.89 2.965
#    internal         0   .0104 45.02                   0          0        127 .2261          13.46 2.397
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 15.19    .1985      .4503         0                  240 825.2 760.4
#    external       0          0 19.39    .1745      .4134         0
#    internal       0          0    11    .2225      .4871         0
#
# 18:31:02 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:31:03 | new best ppl: 15.19 (previous best was 15.27)
# 18:31:03 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:31:06 | time:320s total_exs:4096 total_steps:256 epochs:4.24
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      56.73     1 890.8  8951       0          0 160.8  256             16384  11.47    .1348 15.59 2.815 1e-06 245.1
#    external 61.08                         0          0         97                                   16.69 3.168
#    internal 52.38                         0          0        159                                   14.48 2.461
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2463       0          0 17.74      .4300   .003145                  256 1136 11414 10.05
#    external             0          0 23.77      .3694         0
#    internal             0          0 11.72      .4907   .006289
# 18:31:06 | running eval: valid
# 18:31:20 | eval completed in 13.51s
# 18:31:20 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .01164 53.69 635.2 583.5       0          0 12.96  171 .1960   .06912 14.68 2.677 1e-06   190 174.5
#    external         0 .009789 62.36                   0          0         44 .1634          15.89 2.961
#    internal         0   .0135 45.02                   0          0        127 .2286          13.46 2.393
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb  tps
#    all            0          0 15.13    .1975      .4500         0                  256 825.2  758
#    external       0          0 19.31    .1676      .4134         0
#    internal       0          0 10.94    .2275      .4865         0
#
# 18:31:20 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:31:21 | new best ppl: 15.13 (previous best was 15.19)
# 18:31:21 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:31:22 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:31:25 | time:339s total_exs:4352 total_steps:272 epochs:4.50
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      55.01     1 872.4  9391       0          0 172.2  256             16384  11.26    .1244 14.62 2.688 1e-06 236.2
#    external 56.87                         0          0         95                                   14.03 2.818
#    internal 53.14                         0          0        161                                    15.2 2.559
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2543       0          0 14.83      .4382         0                  272 1109 11934 10.77
#    external             0          0 16.75      .4134         0
#    internal             0          0 12.92      .4630         0
#
# 18:31:25 | running eval: valid
# 18:31:39 | eval completed in 13.32s
# 18:31:39 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .009103 53.69 635.2 593.3       0          0 13.18  171 .2037   .06936 14.68 2.672 1e-06   190 177.5
# ...
#    all       2195       0          0 12.55      .4816         0                  640 1121 11059 9.869
#    external             0          0 14.92      .4590         0
#    internal             0          0 10.18      .5041         0
# 18:38:13 | running eval: valid
# 18:38:26 | eval completed in 13.31s
# 18:38:26 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .009738 53.69 635.2   573       0          0 12.73  171 .2155   .06905 14.68 2.613 1e-06   190 171.4
#    external         0 .004959 62.36                   0          0         44 .1807          15.89 2.898
#    internal         0  .01452 45.02                   0          0        127 .2503          13.46 2.329
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0  14.2    .2102      .4611         0                  640 825.2 744.3
#    external       0          0 18.14    .1743      .4263         0
#    internal       0          0 10.27    .2462      .4959         0
#
# 18:38:26 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:38:28 | new best ppl: 14.2 (previous best was 14.23)
# 18:38:28 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:38:29 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:38:32 | time:766s total_exs:10496 total_steps:656 epochs:10.85
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      52.92     1 844.4  9232       0          0 174.9  256             16384  13.15    .1248 13.61 2.555 1e-06 216.9
#    external 53.37                         0          0         87                                   13.76 2.701
#    internal 52.47                         0          0        169                                   13.46  2.41
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2372       0          0 13.01      .4629   .002959                  656 1061 11603 10.94
#    external             0          0  14.9      .4378         0
#    internal             0          0 11.13      .4881   .005917
#
# 18:38:32 | running eval: valid
# 18:38:44 | eval completed in 12.27s
# 18:38:44 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .009667 53.69 635.2 636.8       0          0 14.15  171 .2128   .06904 14.68 2.612 1e-06   190 190.5
#    external         0 .004959 62.36                   0          0         44 .1775          15.89 2.897
#    internal         0  .01437 45.02                   0          0        127 .2481          13.46 2.327
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 14.18    .2100      .4611         0                  656 825.2 827.2
#    external       0          0 18.12    .1743      .4263         0
#    internal       0          0 10.25    .2456      .4959         0
#
# 18:38:44 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:38:46 | new best ppl: 14.18 (previous best was 14.2)
# 18:38:46 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:38:48 | time:782s total_exs:10752 total_steps:672 epochs:11.12
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all       57.7     1 913.2 10059       0          0 176.2  256             16384  11.12    .1142 13.47 2.492 1e-06 218.4
#    external 61.52                         0          0        107                                   12.36 2.524
#    internal 53.89                         0          0        149                                   14.58 2.459
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2406       0          0 12.09      .4698         0                  672 1132 12465 11.02
#    external             0          0 12.48      .4580         0
#    internal             0          0  11.7      .4816         0
#
# 18:38:48 | running eval: valid
# 18:39:01 | eval completed in 12.40s
# 18:39:01 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0 .009668 53.69 635.2 632.4       0          0 14.05  171 .2169    .0693 14.68  2.61 1e-06   190 189.1
#    external         0 .004959 62.36                   0          0         44 .1793          15.89 2.895
#    internal         0  .01438 45.02                   0          0        127 .2544          13.46 2.325
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 14.16    .2128      .4611         0                  672 825.2 821.5
#    external       0          0 18.09    .1743      .4263         0
#    internal       0          0 10.23    .2514      .4959         0
#
# 18:39:01 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:39:02 | new best ppl: 14.16 (previous best was 14.18)
# 18:39:02 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:39:05 | time:799s total_exs:11008 total_steps:688 epochs:11.38
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      58.11     1 928.6 10045       0          0 173.1  256             16384  11.69    .1477 14.84 2.656 1e-06 234.4
#    external 58.37                         0          0         89                                   15.47 2.874
#    internal 57.86                         0          0        167                                   14.22 2.438
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2536       0          0 14.58      .4413         0                  688 1163 12582 10.82
#    external             0          0  17.7      .4074         0
#    internal             0          0 11.45      .4751         0
#
# 18:39:05 | running eval: valid
# 18:39:17 | eval completed in 12.24s
# 18:39:17 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .01373 53.69 635.2 643.3       0          0 14.29  171 .2188   .06907 14.68 2.609 1e-06   190 192.4
#    external         0  .01308 62.36                   0          0         44 .1899          15.89 2.894
#    internal         0  .01438 45.02                   0          0        127 .2476          13.46 2.324
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 14.14    .2135      .4614         0                  688 825.2 835.7
#    external       0          0 18.06    .1805      .4263         0
#    internal       0          0 10.22    .2466      .4965         0
#
# 18:39:17 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:39:19 | new best ppl: 14.14 (previous best was 14.16)
# 18:39:19 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:39:22 | time:816s total_exs:11264 total_steps:704 epochs:11.65
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      52.33     1 844.3  5689       0          0 107.8  256             16384  11.08    .1218  14.3 2.655 1e-06 231.7
#    external 51.35                         0          0         71                                    13.9 2.786
#    internal 53.31                         0          0        185                                    14.7 2.524
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb  tps  ups
#    all       1561       0          0 14.35      .4363         0                  704 1076 7249 6.74
#    external             0          0 16.22      .4043         0
#    internal             0          0 12.48      .4684         0
# 18:39:22 | running eval: valid
# 18:39:35 | eval completed in 12.25s
# 18:39:35 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .01373 53.69 635.2 641.3       0          0 14.25  171 .2195   .06902 14.68 2.606 1e-06   190 191.8
#    external         0  .01308 62.36                   0          0         44 .1899          15.89 2.891
#    internal         0  .01438 45.02                   0          0        127 .2491          13.46 2.321
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 14.11    .2163      .4620         0                  704 825.2 833.1
#    external       0          0 18.02    .1850      .4263         0
#    internal       0          0 10.19    .2477      .4977         0
#
# 18:39:35 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:39:36 | new best ppl: 14.11 (previous best was 14.14)
# 18:39:36 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:39:37 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:39:40 | time:834s total_exs:11520 total_steps:720 epochs:11.91
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      59.74     1   953 10832       0          0 181.9  256             16384  10.94    .1565 15.34 2.491 1e-06 244.3
#    external 62.01                         0          0        118                                   16.27 2.578
#    internal 57.47                         0          0        138                                   14.41 2.403
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2777       0          0 12.12      .4624         0                  720 1197 13609 11.37
#    external             0          0 13.17      .4396         0
#    internal             0          0 11.06      .4852         0
#
# 18:39:40 | running eval: valid
# 18:39:52 | eval completed in 12.29s
# 18:39:52 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .01373 53.69 635.2 640.2       0          0 14.22  171 .2196   .06909 14.68 2.605 1e-06   190 191.5
#    external         0  .01308 62.36                   0          0         44 .1867          15.89  2.89
#    internal         0  .01438 45.02                   0          0        127 .2525          13.46  2.32
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 14.08    .2178      .4620         0                  720 825.2 831.7
#    external       0          0 17.99    .1850      .4263         0
#    internal       0          0 10.17    .2506      .4977         0
#
# 18:39:52 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:39:54 | new best ppl: 14.08 (previous best was 14.11)
# 18:39:54 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:39:56 | time:850s total_exs:11776 total_steps:736 epochs:12.18
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      57.02     1 906.8  9648       0          0 170.2  256             16384  11.32    .1477 14.81 2.554 1e-06 237.6
#    external 58.27                         0          0         92                                   14.67 2.662
#    internal 55.77                         0          0        164                                   14.95 2.446
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2528       0          0 12.94      .4491         0                  736 1144 12176 10.65
#    external             0          0 14.32      .4193         0
#    internal             0          0 11.55      .4790         0
#
# 18:39:56 | running eval: valid
# 18:40:08 | eval completed in 12.16s
# 18:40:08 | valid:
#              accuracy  bleu-4  clen  ctpb  ctps  ctrunc  ctrunclen  exps  exs    f1  gpu_mem  llen  loss    lr  ltpb  ltps  \
#    all              0  .01373 53.69 635.2 647.8       0          0 14.39  171 .2189   .06919 14.68 2.603 1e-06   190 193.8
#    external         0  .01308 62.36                   0          0         44 .1862          15.89 2.888
#    internal         0  .01438 45.02                   0          0        127 .2516          13.46 2.318
#              ltrunc  ltrunclen   ppl  rouge_L  token_acc  token_em  total_train_updates   tpb   tps
#    all            0          0 14.06    .2163      .4620         0                  736 825.2 841.6
#    external       0          0 17.96    .1825      .4263         0
#    internal       0          0 10.16    .2501      .4977         0
#
# 18:40:09 | saving model checkpoint: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model.checkpoint
# 18:40:10 | new best ppl: 14.06 (previous best was 14.08)
# 18:40:10 | saving best valid model: /home/alex/ParlaiEmely/models/model-runs/blender-internal,external-6,3/model
# 18:40:13 | time:866s total_exs:12032 total_steps:752 epochs:12.44
#              clen  clip  ctpb  ctps  ctrunc  ctrunclen  exps  exs  fp16_loss_scalar  gnorm  gpu_mem  llen  loss    lr  ltpb  \
#    all      57.09     1 922.9  9981       0          0   173  256             16384  10.82    .1142 14.79 2.501 1e-06 235.1
#    external  54.8                         0          0         95                                   15.14  2.65
#    internal 59.38                         0          0        161                                   14.43 2.352
#              ltps  ltrunc  ltrunclen   ppl  token_acc  token_em  total_train_updates  tpb   tps   ups
#    all       2543       0          0 12.33      .4656         0                  752 1158 12524 10.82
#    external             0          0 14.15      .4492         0
#    internal             0          0 10.51      .4819         0
#
# 18:40:13 | running eval: valid

# %% [markdown]
# ## 2. Blender base config + bst
#
# ### Datasets with sampling weights:
# - internal: 6
# - external: 3
# - blended_skill_talk: 1
#
# ### Mutators
# None

# %%
tasks='internal,external,blended_skill_talk'
weights= '6,3,1'

run_training(tasks=tasks,weights=weights)

# %% [markdown]
# ## 3. Blender base + otter
#
# ### Datasets with sampling weights:
# - internal: 6
# - external: 3
# - otter: 1
#
# ### Mutators
# None

# %%
tasks='internal,external,otter'
weights= '6,3,1'

run_training(tasks=tasks,weights=weights)

# %% [markdown]
# ## 4. Blender base + otter and bst
#
# ### Datasets with sampling weights:
# - internal: 6
# - external: 3
# - otter: 1
# - bst: 1
#
# ### Mutators
# None

# %%
tasks='internal,external,otter,blended_skill_talk'
weights= '6,3'

run_training(tasks=tasks,weights=weights)

# %% [markdown]
# # Mutator runs below
#
# Mutators change the dataset
#
# ## 5. Blender base +  word_shuffle
#
# ### Datasets with sampling weights:
# - internal: 6
# - external: 3
#
#
# ### Mutators
# - word_shuffle

# %%
tasks='internal,external'
weights= '6,3'
mutators = 'word_shuffle'

run_training(tasks=tasks, weights=weights, mutators=mutators)

# %% [markdown]
# ## 6. Blender base +  last_turn
#
# ### Datasets with sampling weights:
# - internal: 6
# - external: 3
#
#
# ### Mutators
# - last turn

# %%
tasks='internal,external'
weights= '6,3'
mutators = 'last_turn'

run_training(tasks=tasks, weights=weights, mutators=mutators)

# %% [markdown]
# ## 7. Blender base + flatten

# %%
tasks='internal,external'
weights= '6,3'
mutators = 'flatten'

run_training(tasks=tasks, weights=weights, mutators=mutators)

# %% [markdown]
# ## 8. Blender base + mixed mutators
#
# ### Datasets with sampling weights:
# - internal: 6
# - external: 3
#
#
# ### Mutators
# - None
# - word_shuffle
# - flatten
# - last_turn

# %%
tasks = 'internal,external'
weights= '2,1'
mutators = 'word_shuffle,flatten,last_turn'

run_training(tasks=tasks, weights=weights, mutators=mutators)
